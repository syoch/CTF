# %%
from typing import Generator

# PNG
Pixel = tuple[int, int, int, int]
Chunk = tuple[bytes, bytes]


def read_png(png_data: bytes) -> Generator[Chunk]:
    # hdr = png_data[0:8]
    png_data = png_data[8:]

    while png_data:
        length = int.from_bytes(png_data[0:4], "big")
        name = png_data[4:8]
        png_data = png_data[8:]
        data = png_data[:length]
        png_data = png_data[length + 4 :]

        yield (name, data)


def get_pixels_left(row_data: bytes) -> Generator[Pixel]:
    current_pixel: Pixel = (0, 0, 0, 0)

    while row_data:
        current_pixel = (
            (current_pixel[0] + row_data[0]) % 0x100,
            (current_pixel[1] + row_data[1]) % 0x100,
            (current_pixel[2] + row_data[2]) % 0x100,
            (current_pixel[3] + row_data[3]) % 0x100,
        )
        row_data = row_data[4:]
        yield current_pixel

# %%
import string


a = "268 413 438 313 426 337 272 188 392 338 77 332 139 113 92 239 247 120 419 72 295 190 131"
a = [int(x) for x in a.split(" ")]

charset = string.ascii_lowercase + string.digits + "_"
print(f"Charset: {len(charset)} characters")
print(charset)

def modinv(n, m = len(charset)):
    for i in range(0, m + 1):
        if (n * i) % m == 1:
            return charset[i - 1]
    return "?"

flag = [modinv(n % 41, 41) for n in a]
flag = "".join(flag)

print(flag)
# Out:
# Charset: 37 characters
# abcdefghijklmnopqrstuvwxyz0123456789_
# 1nv3r53ly_h4rd_8a05d939

# %%
from gmpy2 import invert, powmod, mpz, mpfr, rootn, get_context

get_context().precision = 4096

N = ...
E = 20
C = ...
# phi = (p - 1) * (q - 1) (cannot find p, q since N is too large)
# d = invert(E, phi)
# C = powmod(m, d, N)
m = int(rootn(C, E))
print(bytes.fromhex(hex(m)[2:]).decode(errors='ignore'))
# Out:
# picoCTF{t1ny_e_ee65653a}

# %%
A = "heTfl g as iicpCTo{7F4NRP051N5_16_35P3X51N3_V6E5926A}4"
# Split by 3 characters
chunks = [A[i:i+3] for i in range(0, len(A), 3)]

flag = ""
for i, chunk in enumerate(chunks):
    if i % 2 == 0:
        a, b, c = chunk
        flag += f"{c}{a}{b}"
    elif i % 2 == 1:
        a, b, c = chunk
        flag += f"{c}{a}{b}"
print(flag)
# Out:
# The flag is picoCTF{7R4N5P051N6_15_3XP3N51V3_56E6924A}

# %%
str_A = "picoCTF"
str_B = "cvpbPGS"

for a, b in zip(str_A, str_B):
    x = (ord(a) - ord(b)) % 256
    y = (ord(a) ^ ord(b)) % 256
    if x > 128:
        x -= 256
    print(f"a: {a}, b: {b} => (a - b) % 256 = {x}, (a ^ b) % 256 = {y}")
# Out:
# a: p, b: c => (a - b) % 256 = 13, (a ^ b) % 256 = 19
# a: i, b: v => (a - b) % 256 = -13, (a ^ b) % 256 = 31
# a: c, b: p => (a - b) % 256 = -13, (a ^ b) % 256 = 19
# a: o, b: b => (a - b) % 256 = 13, (a ^ b) % 256 = 13
# a: C, b: P => (a - b) % 256 = -13, (a ^ b) % 256 = 19
# a: T, b: G => (a - b) % 256 = 13, (a ^ b) % 256 = 19
# a: F, b: S => (a - b) % 256 = -13, (a ^ b) % 256 = 21

# %%
S = """
OHNFUMWSVZLXEGCPTAJDYIRKQB

Suauypcg Xuwaogf oacju, rvds o waoiu ogf jdoduxq ova, ogf hacywsd eu dsu huudxu
mace o wxojj noju vg rsvns vd roj ugnxcjuf. Vd roj o huoydvmyx jnoaohouyj, ogf, od
dsod dveu, yglgcrg dc godyaoxvjdj—cm ncyaju o wauod pavbu vg o jnvugdvmvn pcvgd
cm ivur. Dsuau ruau drc acygf hxonl jpcdj guoa cgu ukdauevdq cm dsu honl, ogf o
xcgw cgu guoa dsu cdsua. Dsu jnoxuj ruau uknuufvgwxq soaf ogf wxcjjq, rvds oxx dsu
oppuoaognu cm hyagvjsuf wcxf. Dsu ruvwsd cm dsu vgjund roj iuaq aueoalohxu, ogf,
dolvgw oxx dsvgwj vgdc ncgjvfuaodvcg, V ncyxf soafxq hxoeu Zypvdua mca svj cpvgvcg
aujpundvgw vd.

Dsu mxow vj: pvncNDM{5YH5717Y710G_3I0XY710G_03055505}
"""

conversion_table = {
    c.lower(): chr(ord('a') + i)
    for i, c in enumerate("OHNFUMWSVZLXEGCPTAJDYIRKQB")
}
decoded = ""
for c in S:
    lower_c = c.lower()
    if lower_c in conversion_table:
        new_c = conversion_table[lower_c]
        if c.isupper():
            new_c = new_c.upper()
        decoded += new_c.lower()
    else:
        decoded += c.upper()

print(decoded)

# %%
import string

S = """     """

alphabet_frequency_order = "etaoinshrdlcumwfgypbvkjxqz"

conversion_table = {}
print(conversion_table)

decoded = S.translate(str.maketrans(
    {v1.lower(): v2.upper() for v1, v2 in conversion_table.items()} |
    {v1.upper(): v2.upper() for v1, v2 in conversion_table.items()}
))


for line in decoded.splitlines():
    line = "".join(
        c if c in string.ascii_uppercase
        else f"\x1b[31m{c}\x1b[0m"
        for c in line
    )
    print(line)
# Out:
# {}

# %%
import string

S = """
------------------------------------------------------------------------------
rtsmcvpn zdcd yn jthc auvm - acdqhdsrj_yn_r_tldc_uvoebv_ve75359v
-------------------------------------------------------------------------------
vudgdj ajtbtctlyprz wvcvovitl kvn pzd pzycb nts ta ajtbtc fvlutlyprz wvcvovitl,
v uvsb tksdc kduu wstks ys thc bynpcyrp ys zyn tks bvj, vsb npyuu cdodoedcdb
votsm hn tkysm pt zyn muttoj vsb pcvmyr bdvpz, kzyrz zvffdsdb pzycpdds jdvcn
vmt, vsb kzyrz y nzvuu bdnrcyed ys ypn fctfdc fuvrd. atc pzd fcdndsp y kyuu tsuj
nvj pzvp pzyn uvsbtksdcatc nt kd hndb pt rvuu zyo, vupzthmz zd zvcbuj nfdsp v bvj
ta zyn uyad ts zyn tks dnpvpdkvn v npcvsmd pjfd, jdp tsd fcdppj acdqhdspuj pt ed
odp kypz, v pjfd vexdrp vsb lyrythn vsb vp pzd nvod pyod ndsndudnn. ehp zd kvn
tsd ta pztnd ndsndudnn fdcntsn kzt vcd ldcj kduu rvfveud ta uttwysm vapdc pzdyc
ktcubuj vaavycn, vsb, vffvcdspuj, vapdc stpzysm dund. ajtbtc fvlutlyprz, atc
ysnpvsrd, edmvs kypz sdgp pt stpzysm; zyn dnpvpd kvn ta pzd novuudnp; zd cvs pt
bysd vp tpzdc ods'n pveudn, vsb avnpdsdb ts pzdo vn v ptvbj, jdp vp zyn bdvpz yp
vffdvcdb pzvp zd zvb v zhsbcdb pzthnvsb ctheudn ys zvcb rvnz. vp pzd nvod pyod,
zd kvn vuu zyn uyad tsd ta pzd otnp ndsndudnn, avspvnpyrvu aduutkn ys pzd kztud
bynpcyrp. y cdfdvp, yp kvn stp nphfybypjpzd ovxtcypj ta pzdnd avspvnpyrvu aduutkn
vcd nzcdkb vsb yspduuymdsp dsthmzehp xhnp ndsndudnnsdnn, vsb v fdrhuyvc svpytsvu
atco ta yp.
"""

alphabet_frequency_order = "etaoinshrdlcumwfgypbvkjxqz"

conversion_table = {
    "v": "t","s": "h","b": "e",
}
print(conversion_table)

decoded = S.translate(str.maketrans(
    {v1.lower(): v2.upper() for v1, v2 in conversion_table.items()} |
    {v1.upper(): v2.upper() for v1, v2 in conversion_table.items()}
))


for line in decoded.splitlines():
    line = "".join(
        c if c in string.ascii_uppercase
        else f"\x1b[31m{c}\x1b[0m"
        for c in line
    )
    print(line)
# Out:
# {'v': 't', 's': 'h', 'b': 'e'}
#
# ------------------------------------------------------------------------------
# rtHmcTpn zdcd yn jthc auTm - acdqhdHrj_yn_r_tldc_uToeET_Te75359T
# -------------------------------------------------------------------------------
# Tudgdj ajtEtctlyprz wTcToTitl kTn pzd pzycE ntH ta ajtEtc fTlutlyprz wTcToTitl,
# T uTHE tkHdc kduu wHtkH yH thc Eynpcyrp yH zyn tkH ETj, THE npyuu cdodoedcdE
# TotHm hn tkyHm pt zyn muttoj THE pcTmyr EdTpz, kzyrz zTffdHdE pzycpddH jdTcn
# Tmt, THE kzyrz y nzTuu Ednrcyed yH ypn fctfdc fuTrd. atc pzd fcdndHp y kyuu tHuj
# nTj pzTp pzyn uTHEtkHdcatc nt kd hndE pt rTuu zyo, Tupzthmz zd zTcEuj nfdHp T ETj
# ta zyn uyad tH zyn tkH dnpTpdkTn T npcTHmd pjfd, jdp tHd fcdppj acdqhdHpuj pt ed
# odp kypz, T pjfd Texdrp THE lyrythn THE Tp pzd nTod pyod ndHndudnn. ehp zd kTn
# tHd ta pztnd ndHndudnn fdcntHn kzt Tcd ldcj kduu rTfTeud ta uttwyHm Tapdc pzdyc
# ktcuEuj TaaTycn, THE, TffTcdHpuj, Tapdc HtpzyHm dund. ajtEtc fTlutlyprz, atc
# yHnpTHrd, edmTH kypz Hdgp pt HtpzyHm; zyn dnpTpd kTn ta pzd noTuudnp; zd cTH pt
# EyHd Tp tpzdc odH'n pTeudn, THE aTnpdHdE tH pzdo Tn T ptTEj, jdp Tp zyn EdTpz yp
# TffdTcdE pzTp zd zTE T zhHEcdE pzthnTHE ctheudn yH zTcE rTnz. Tp pzd nTod pyod,
# zd kTn Tuu zyn uyad tHd ta pzd otnp ndHndudnn, aTHpTnpyrTu aduutkn yH pzd kztud
# Eynpcyrp. y cdfdTp, yp kTn Htp nphfyEypjpzd oTxtcypj ta pzdnd aTHpTnpyrTu aduutkn
# Tcd nzcdkE THE yHpduuymdHp dHthmzehp xhnp ndHndudnnHdnn, THE T fdrhuyTc HTpytHTu
# atco ta yp.

# %%
S = """
------------------------------------------------------------------------------
rtsmcvpn zdcd yn jthc auvm - acdqhdsrj_yn_r_tldc_uvoebv_ve75359v
-------------------------------------------------------------------------------
vudgdj ajtbtctlyprz wvcvovitl kvn pzd pzycb nts ta ajtbtc fvlutlyprz wvcvovitl, v uvsb tksdc kduu wstks ys thc bynpcyrp ys zyn tks bvj, vsb npyuu cdodoedcdb votsm hn tkysm pt zyn muttoj vsb pcvmyr bdvpz, kzyrz zvffdsdb pzycpdds jdvcn vmt, vsb kzyrz y nzvuu bdnrcyed ys ypn fctfdc fuvrd. atc pzd fcdndsp y kyuu tsuj nvj pzvp pzyn uvsbtksdcatc nt kd hndb pt rvuu zyo, vupzthmz zd zvcbuj nfdsp v bvj ta zyn uyad ts zyn tks dnpvpdkvn v npcvsmd pjfd, jdp tsd fcdppj acdqhdspuj pt ed odp kypz, v pjfd vexdrp vsb lyrythn vsb vp pzd nvod pyod ndsndudnn. ehp zd kvn tsd ta pztnd ndsndudnn fdcntsn kzt vcd ldcj kduu rvfveud ta uttwysm vapdc pzdyc ktcubuj vaavycn, vsb, vffvcdspuj, vapdc stpzysm dund. ajtbtc fvlutlyprz, atc ysnpvsrd, edmvs kypz sdgp pt stpzysm; zyn dnpvpd kvn ta pzd novuudnp; zd cvs pt bysd vp tpzdc ods'n pveudn, vsb avnpdsdb ts pzdo vn v ptvbj, jdp vp zyn bdvpz yp vffdvcdb pzvp zd zvb v zhsbcdb pzthnvsb ctheudn ys zvcb rvnz. vp pzd nvod pyod, zd kvn vuu zyn uyad tsd ta pzd otnp ndsndudnn, avspvnpyrvu aduutkn ys pzd kztud bynpcyrp. y cdfdvp, yp kvn stp nphfybypjpzd ovxtcypj ta pzdnd avspvnpyrvu aduutkn vcd nzcdkb vsb yspduuymdsp dsthmzehp xhnp ndsndudnnsdnn, vsb v fdrhuyvc svpytsvu atco ta yp.
"""
s = "".join(
    chr(ord('a') + (26  + ord(c) - ord('a') - 10) % 26) if c.islower() else
    chr(ord('A') + (26  + ord(c) - ord('A') - 10) % 26) if c.isupper() else
    c
    for c in S
)
print(s)
# Out:
# ------------------------------------------------------------------------------
# hjicslfd ptst od zjxs qklc - qstgxtihz_od_h_jbts_kleurl_lu75359l
# -------------------------------------------------------------------------------
# lktwtz qzjrjsjbofhp mlslelyjb ald fpt fposr dji jq qzjrjs vlbkjbofhp mlslelyjb, l klir jaits atkk mijai oi jxs rodfsohf oi pod jai rlz, lir dfokk steteutstr lejic xd jaoic fj pod ckjjez lir fslcoh rtlfp, apohp plvvtitr fposftti ztlsd lcj, lir apohp o dplkk rtdhsout oi ofd vsjvts vklht. qjs fpt vstdtif o aokk jikz dlz fplf fpod klirjaitsqjs dj at xdtr fj hlkk poe, lkfpjxcp pt plsrkz dvtif l rlz jq pod koqt ji pod jai tdflftald l dfslict fzvt, ztf jit vstffz qstgxtifkz fj ut etf aofp, l fzvt lunthf lir bohojxd lir lf fpt dlet foet dtidtktdd. uxf pt ald jit jq fpjdt dtidtktdd vtsdjid apj lst btsz atkk hlvlukt jq kjjmoic lqfts fptos ajskrkz lqqlosd, lir, lvvlstifkz, lqfts ijfpoic tkdt. qzjrjs vlbkjbofhp, qjs oidfliht, utcli aofp itwf fj ijfpoic; pod tdflft ald jq fpt delkktdf; pt sli fj roit lf jfpts eti'd fluktd, lir qldftitr ji fpte ld l fjlrz, ztf lf pod rtlfp of lvvtlstr fplf pt plr l pxirstr fpjxdlir sjxuktd oi plsr hldp. lf fpt dlet foet, pt ald lkk pod koqt jit jq fpt ejdf dtidtktdd, qlifldfohlk qtkkjad oi fpt apjkt rodfsohf. o stvtlf, of ald ijf dfxvorofzfpt elnjsofz jq fptdt qlifldfohlk qtkkjad lst dpstar lir oiftkkoctif tijxcpuxf nxdf dtidtktdditdd, lir l vthxkols ilfojilk qjse jq of.

# %%
import string

LOWERCASE_OFFSET = ord("a")
ALPHABET = string.ascii_lowercase[:16]

def b16_decode(enc):
    plain = ""
    for i in range(0, len(enc), 2):
        t1 = ALPHABET.index(enc[i])
        t2 = ALPHABET.index(enc[i + 1])
        binary = "{0:04b}{1:04b}".format(t1, t2)
        plain += chr(int(binary, 2))
    return plain

def shift(c, k):
	t1 = ord(c) - LOWERCASE_OFFSET
	t2 = ord(k) - LOWERCASE_OFFSET
	return ALPHABET[(t1 - t2) % len(ALPHABET)]

b16 = "lkmjkemjmkiekeijiiigljlhilihliikiliginliljimiklligljiflhiniiiniiihlhilimlhijil"

for k in ALPHABET:
    msg = "".join(
         shift(c, k)
         for i, c in enumerate(b16)
    )
    msg = b16_decode(msg)
    if all(c in string.printable for c in msg):
        print(f"Keys: {k} => Message: {msg}")
# Out:
# Keys: f => Message: et_tu?_431db62c5618cd75f1d0b83832b67b46
# Keys: g => Message: TcNcd.N#" SQ%!R$% 'RS&$U S/Q'"'"!Q%&Q#%
